# %%
stack = []
capacity = 5

def isFull():
    if len(stack) == capacity:
        return True
    else:
        return False

def isEmpty():
    if len(stack) == 0:
        return True
    else:
        return False

def push(data):
    if isFull():
        print('Stack이 차 잇어서 더 이상 추가 할 수 없습니다')
    else:
        stack.append(data)

def pop():
    if isEmpty():
        print('stack이 비어있습니다.')
        return - 1
    else:
        return stack.pop()

def peek():
    if isEmpty():
        print('stack이 비어있습니다.')
        return - 1
    else:
        return stack[-1]



print('============================================================')
print(f'[[정수형 스택 연산 실습 (용량 : {capacity})]]')
print('1.push 2.pop 3.peek 0.exit')
print('============================================================')

while True:
    menu = int(input('>메뉴 선택 : '))
    if menu  == 0:
        break
    elif menu == 1:
        data = int(input('데이터 입력'))
        push(data)
    elif menu == 2:
        data = pop()
        print('')
    elif menu == 3:
        data = peek()
        print('가져올 데이터:', stack[-1])
        
        
    
    print('>현재 스택 상태', stack)

print('[[정수형 스택 연산 실습 종료]]')
# Out:
# ============================================================
# [[정수형 스택 연산 실습 (용량 : 5)]]
# 1.push 2.pop 3.peek 0.exit
# ============================================================
# >메뉴 선택 :  3
# stack이 비어있습니다.
# 가져올 데이터: []
# >현재 스택 상태 []
# >메뉴 선택 :  1
# 데이터 입력 2
# >현재 스택 상태 [2]
# >메뉴 선택 :  1
# 데이터 입력 3
# >현재 스택 상태 [2, 3]
# >메뉴 선택 :  3
# 가져올 데이터: [2, 3]
# >현재 스택 상태 [2, 3]
